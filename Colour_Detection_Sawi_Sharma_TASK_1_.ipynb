# %% [markdown]
# ## THE SPARKS FOUNDATION
# # **TASK 1: Colour Identification in Images**
# Level : Beginner
#
# ## **Performed by : Sawi Sharma**

# %% [markdown]
# ![colourful wallpaper.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Importing Libraries

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import cv2
from collections import Counter
from skimage.color import rgb2lab, deltaE_cie76
from google.colab.patches import cv2_imshow
import os

# %matplotlib inline

# %% [markdown]
# Importing image

# %%
img=cv2.imread('colourful wallpaper.jpg')
plt.imshow(img)

# %%
#converting the colour from BGR to RGB
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# Extracting the colour form the image.

# %%
#function to get RGB image from default BGR image
def get_image(image_link):
  image=cv2.imread(image_link)
  image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  return image

# %%
def get_colors(image,number_of_colours):
  modif_image=cv2.resize(image,(400,300))
  modif_image = modif_image.reshape(modif_image.shape[0]*modif_image.shape[1], 3)
  clf=KMeans(n_clusters=number_of_colours)
  labels=clf.fit_predict(modif_image)
  counts=Counter(labels)
  counts=dict(sorted(counts.items()))
  centre_colours=clf.cluster_centers_
  ordered_colours=[centre_colours[i] for i in counts.keys()]
  rgb_colours = [ordered_colours[i] for i in counts.keys()]
  return rgb_colours

# %%
get_colors(get_image('colourful wallpaper.jpg'), 8)
# Out:
# [array([106.02674062,  33.84619194,  41.1720313 ]),
#  array([ 10.58846087,  70.17883911, 199.9780373 ]),
#  array([20.13484578, 11.57921234, 20.50885802]),
#  array([206.17770391,   9.49974431, 107.30759397]),
#  array([226.36131914, 113.91078702, 196.13335961]),
#  array([230.28261381, 150.09645068,  11.10060331]),
#  array([ 21.91810494,  44.94062824, 108.52148775]),
#  array([ 23.38345594, 165.44338701, 197.5664386 ])]

# %% [markdown]
# END OF PROJECT
